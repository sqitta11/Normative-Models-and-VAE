# %%
import pandas as pd

# %%
final_df = pd.read_csv("/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/final_data/Final_data.csv")
final_df = final_df.iloc[:,2:]
final_df
# Out:
#        SubjectID  3rd-Ventricle  4th-Ventricle  5th-Ventricle  Brain-Stem  \
# 0        1533138        36.8674        31.3818            0.0     81.5837
# 1        1875529        31.3638        30.1527            0.0     83.1511
# 2        4758824        35.0732        36.2819            0.0     84.1654
# 3        5304207        41.5897        33.3825            0.0     84.4920
# 4        2747983        42.9063        33.2600            0.0     83.8396
# ...          ...            ...            ...            ...         ...
# 33937    3463731        35.1942        33.5758            0.0     84.6992
# 33938    3814047        36.9796        33.8569            0.0     82.1534
# 33939    4851516        31.9402        32.7079            0.0     84.1758
# 33940    3626816        42.8421        34.9272            0.0     84.0678
# 33941    2420905        29.5598        29.2897            0.0     83.6442
#
#        CC_Anterior  CC_Central  CC_Mid_Anterior  CC_Mid_Posterior  \
# 0         100.2311     94.2112          93.9213           89.7624
# 1          95.3329     89.9717          90.3416           85.7553
# 2          99.6201     95.3489          95.4416           93.4878
# 3         104.1299     93.2735          95.2359           95.4301
# 4         103.1391     92.3403          90.9298           94.4794
# ...            ...         ...              ...               ...
# 33937     102.1988     93.7001          92.8186           93.6035
# 33938     100.7485     96.7414          94.8558           92.6987
# 33939      98.3044     92.3463          91.8287           87.2853
# 33940     105.3313     94.4410          91.4660           91.4544
# 33941      96.4966     76.8742          79.7448           77.8902
#
#        CC_Posterior  ...  rh_S_pericallosal_thickness  \
# 0          101.8197  ...                        1.965
# 1          100.0998  ...                        2.407
# 2          101.0905  ...                        1.793
# 3          102.7365  ...                        1.782
# 4           99.5247  ...                        1.927
# ...             ...  ...                          ...
# 33937      101.7283  ...                        1.648
# 33938      101.3991  ...                        1.963
# 33939       99.0109  ...                        2.461
# 33940      100.9750  ...                        2.071
# 33941       89.2514  ...                        1.608
#
#        rh_S_postcentral_thickness  rh_S_precentral-inf-part_thickness  \
# 0                           2.227                               2.672
# 1                           2.016                               2.794
# 2                           2.397                               2.537
# 3                           2.377                               2.501
# 4                           2.579                               2.863
# ...                           ...                                 ...
# 33937                       2.351                               2.870
# 33938                       2.245                               2.408
# 33939                       2.173                               2.552
# 33940                       2.475                               2.698
# 33941                       2.645                               2.755
#
#        rh_S_precentral-sup-part_thickness  rh_S_temporal_sup_thickness  \
# 0                                   2.561                        2.735
# 1                                   2.706                        2.676
# 2                                   2.547                        2.684
# 3                                   2.696                        2.746
# 4                                   2.843                        2.829
# ...                                   ...                          ...
# 33937                               2.696                        2.851
# 33938                               2.523                        2.536
# 33939                               2.408                        2.845
# 33940                               2.665                        3.171
# 33941                               2.845                        2.866
#
#        Year_initial_scan  Sex  Birthyear  Age     Site
# 0                   2010  0.0       1950   60  11025.0
# 1                   2008  0.0       1948   60  11025.0
# 2                   2008  0.0       1946   62  11025.0
# 3                   2010  0.0       1963   47  11025.0
# 4                   2008  0.0       1963   45  11025.0
# ...                  ...  ...        ...  ...      ...
# 33937               2008  0.0       1957   51  11027.0
# 33938               2007  1.0       1960   47  11025.0
# 33939               2009  1.0       1940   69  11027.0
# 33940               2008  1.0       1961   47  11025.0
# 33941               2009  0.0       1949   60  11025.0
#
# [33942 rows x 117 columns]

# %% [markdown]
# 42018	Date of all cause dementia report
# 42020	Date of alzheimer's disease report
# 42024	Date of frontotemporal dementia report
# 42022	Date of vascular dementia report
# 42019	Source of all cause dementia report
# 42021	Source of alzheimer's disease report
# 42025	Source of frontotemporal dementia report
# 42023	Source of vascular dementia report
#
#
# for file in *; do
#     if [ -f "$file" ]; then
#         echo "Checking file: $file"
#         head -n 1 "$file" | grep -qE '42018|42020|42024|42022|42019|42021|42025|42023' && echo "Match found in $file"
#     fi
# done
#
#
# Match found in ukb41577.csv
# Match found in ukb43578.csv
# Match found in ukb49422.csv
# Match found in ukb49424.csv
# Match found in ukb49424_headers.csv
# Match found in ukb673406.csv
# Match found in ukb673408.csv

# %%
health_outcome_df = pd.read_csv("/project_cephfs/3022017.06/UKB/phenotypes/ukb43578.csv")
health_outcome_df = health_outcome_df.rename(columns={"eid":"SubjectID"})
health_outcome_df
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# /scratch/quirom/slurm_job_51029688/ipykernel_2123875/1204236315.py:1: DtypeWarning: Columns (639,641,663,664,665,666,3604,3683,3685,3687,3691,3693,3699,3701,3703,3705,3707,3709,3711,3713,3717,3719,3721,3723,3725,3727,3729,3731,3733,3735,3737,3739,3743,3745,3747,3749,3751,3753,3755,3757,3759,3761,3765) have mixed types. Specify dtype option on import or set low_memory=False.
#   health_outcome_df = pd.read_csv("/project_cephfs/3022017.06/UKB/phenotypes/ukb43578.csv")
