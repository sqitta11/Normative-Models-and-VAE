# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df_pca  = pd.read_csv("/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/Data/A1_2_PCA_training_data.csv")
df_pca = df_pca.iloc[:,1:]

df_demo = df_pca.iloc[:,:5]
df_demo = df_demo.reset_index(drop=True)

df_pca = df_pca.drop(columns=["Dataset", "Diagnosis"])
#original data 
# scaler = StandardScaler()
# data_scaled = scaler.fit_transform(df_pca)
df_pca
# Out:
#        Age  Sex     Site  lh_G_front_inf-Triangul_thickness  \
# 0     52.0  0.0  11027.0                              3.032
# 1     62.0  0.0  11025.0                              2.970
# 2     60.0  0.0  11025.0                              2.934
# 3     54.0  0.0  11025.0                              3.011
# 4     65.0  1.0  11027.0                              2.778
# ...    ...  ...      ...                                ...
# 4673  59.0  0.0  11027.0                              3.362
# 4674  59.0  1.0  11027.0                              2.768
# 4675  56.0  0.0  11025.0                              3.168
# 4676  46.0  1.0  11025.0                              3.120
# 4677  60.0  1.0  11026.0                              3.120
#
#       lh_G_front_middle_thickness  lh_G_front_sup_thickness  \
# 0                           2.910                     3.124
# 1                           2.705                     2.838
# 2                           2.995                     3.182
# 3                           3.049                     3.199
# 4                           2.697                     2.900
# ...                           ...                       ...
# 4673                        3.085                     3.318
# 4674                        2.670                     2.920
# 4675                        2.805                     3.047
# 4676                        2.839                     3.302
# 4677                        2.927                     3.096
#
#       lh_G_oc-temp_lat-fusifor_thickness  lh_G_oc-temp_med-Lingual_thickness  \
# 0                                  3.121                               1.950
# 1                                  3.197                               1.861
# 2                                  3.291                               2.167
# 3                                  3.315                               2.035
# 4                                  2.718                               1.995
# ...                                  ...                                 ...
# 4673                               3.269                               2.099
# 4674                               3.116                               1.886
# 4675                               3.117                               2.179
# 4676                               3.331                               2.192
# 4677                               3.025                               2.180
#
#       lh_G_oc-temp_med-Parahip_thickness  lh_G_occipital_middle_thickness  \
# 0                                  3.121                            2.913
# 1                                  3.026                            2.655
# 2                                  3.692                            2.766
# 3                                  3.361                            2.685
# 4                                  2.906                            2.475
# ...                                  ...                              ...
# 4673                               3.520                            2.677
# 4674                               2.952                            2.530
# 4675                               3.243                            2.642
# 4676                               3.269                            2.795
# 4677                               3.143                            2.540
#
#       ...  Right-Cerebellum-White-Matter  Right-Hippocampus  \
# 0     ...                        13226.6             4475.2
# 1     ...                        13410.2             3380.5
# 2     ...                        18425.6             4954.1
# 3     ...                        14006.0             4268.6
# 4     ...                        15383.1             4198.7
# ...   ...                            ...                ...
# 4673  ...                        15117.0             3671.1
# 4674  ...                        15243.3             3828.4
# 4675  ...                        12206.2             3677.9
# 4676  ...                        15843.8             4524.9
# 4677  ...                        13733.7             4502.1
#
#       Right-Inf-Lat-Vent  Right-Lateral-Ventricle  Right-Pallidum  \
# 0                  125.1                   3713.2          1775.9
# 1                  140.1                   6363.8          1558.5
# 2                  483.6                  12932.1          2095.6
# 3                  244.9                  10023.3          1652.6
# 4                  821.0                  17129.7          1875.9
# ...                  ...                      ...             ...
# 4673               241.1                   6140.5          2054.6
# 4674               480.9                  18586.3          2066.9
# 4675               271.4                   6810.7          1565.7
# 4676               152.0                   6962.5          2046.1
# 4677               786.6                  25520.5          2031.0
#
#       Right-Putamen  Right-VentralDC  Right-choroid-plexus  Right-vessel  \
# 0            4594.2           3735.1                 261.6          20.9
# 1            3867.5           3149.8                 314.2          19.1
# 2            4804.5           4831.3                 544.7           4.9
# 3            4262.7           3669.4                 615.4          28.5
# 4            4218.5           3865.6                1066.2          58.5
# ...             ...              ...                   ...           ...
# 4673         4460.6           3757.5                 568.4          49.7
# 4674         5476.6           4230.8                 920.3          12.3
# 4675         4131.6           2944.3                 372.4          43.8
# 4676         5376.9           4255.2                 478.9          38.2
# 4677         4849.6           3776.9                1099.4          58.2
#
#       WM-hypointensities
# 0                 2143.1
# 1                 1799.1
# 2                 1400.7
# 3                  890.7
# 4                 1733.5
# ...                  ...
# 4673              1826.3
# 4674              1430.4
# 4675               819.2
# 4676              1273.3
# 4677              1766.6
#
# [4678 rows x 106 columns]

# %%
x = df_pca

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

pca = PCA(n_components=10)
x_pca = pca.fit_transform(x_scaled)

cummulative_variance = 0
for i, var in enumerate(pca.explained_variance_ratio_, start=1):
    cummulative_variance += var
    if i < 10: 
        print(f'PC{i}:    Cummulative variance:  {cummulative_variance:.2%},  Individual variance:  {var:.2%}')
    else:
        print(f'PC{i}:   Cummulative variance:  {cummulative_variance:.2%},  Individual variance:  {var:.2%}')

#plot
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, alpha=0.6, label='Individual explained variance')
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_), 'r-', label='Cumulative explained variance')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance by Principal Components')
plt.legend()
plt.show()
# Out:
# PC1:    Cummulative variance:  32.81%,  Individual variance:  32.81%
# PC2:    Cummulative variance:  43.44%,  Individual variance:  10.63%
# PC3:    Cummulative variance:  49.34%,  Individual variance:  5.90%
# PC4:    Cummulative variance:  52.24%,  Individual variance:  2.90%
# PC5:    Cummulative variance:  55.04%,  Individual variance:  2.80%
# PC6:    Cummulative variance:  57.18%,  Individual variance:  2.14%
# PC7:    Cummulative variance:  59.08%,  Individual variance:  1.90%
# PC8:    Cummulative variance:  60.67%,  Individual variance:  1.59%
# PC9:    Cummulative variance:  62.24%,  Individual variance:  1.56%
# PC10:   Cummulative variance:  63.63%,  Individual variance:  1.40%

# %%
pca_df = pd.DataFrame(x_pca[:, :4], columns=['PC1', 'PC2', 'PC3', 'PC4'])
pca_df = pd.concat([pca_df, df_demo], axis=1)

min_age = pca_df["Age"].min()
max_age = pca_df["Age"].max()

bins = np.arange(np.floor(min_age / 5) * 5, np.ceil(max_age / 5) * 5 + 1, 5)

pca_df['AgeGroup'] = pd.cut(
    pca_df['Age'],
    bins=bins,
    labels = [f"{int(bins[i])}-{int(bins[i+1]-1)}" for i in range(len(bins)-1)],
    right=False
)

# plot
sns.pairplot(pca_df, hue="AgeGroup", vars=['PC1', 'PC2', 'PC3', 'PC4'], palette="tab20")
plt.suptitle('plot of first 4 principal components for each age group', y=1.02)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

x_recon = pca.inverse_transform(x_pca)
mse = mean_squared_error(x_scaled, x_recon)
mae = mean_absolute_error(x_scaled, x_recon)
r2 = r2_score(x_scaled, x_recon)
print(f"MSE: {mse:.4f}\nMAE: {mae:.4f}\nR²: {r2:.4f}")
# Out:
# MSE: 0.3637
# MAE: 0.4593
# R²: 0.6363

# %%
#now only transform the unseen data to see how well the PCA encodes for the different variables
df_pca  = pd.read_csv("/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/Data/A2_unseen_data_ukb_adni_o3.csv")
df_pca = df_pca.iloc[:,1:]

df_pca = df_pca.drop(columns=["Dataset", "Diagnosis"])
df_pca = df_pca.dropna()

x_scaled = scaler.transform(df_pca)
pca_features = pca.transform(x_scaled)
x_recon = pca.inverse_transform(pca_features)
mse = mean_squared_error(x_scaled, x_recon)
mae = mean_absolute_error(x_scaled, x_recon)
r2 = r2_score(x_scaled, x_recon)
print(f"MSE: {mse:.4f}\nMAE: {mae:.4f}\nR²: {r2:.4f}\n")


plt.style.use("dark_background")

cummulative_variance = 0
for i, var in enumerate(pca.explained_variance_ratio_, start=1):
    cummulative_variance += var
    if i < 10: 
        print(f'PC{i}:    Cummulative variance:  {cummulative_variance:.2%},  Individual variance:  {var:.2%}')
    else:
        print(f'PC{i}:   Cummulative variance:  {cummulative_variance:.2%},  Individual variance:  {var:.2%}')

#plot
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, color='coral', label='Individual explained variance')
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_), color='white', label='Cumulative explained variance')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance by Principal Components (Baseline model)')
plt.legend()
plt.show()
# Out:
# MSE: 0.4557
# MAE: 0.4929
# R²: 0.7161
#
# PC1:    Cummulative variance:  32.81%,  Individual variance:  32.81%
# PC2:    Cummulative variance:  43.44%,  Individual variance:  10.63%
# PC3:    Cummulative variance:  49.34%,  Individual variance:  5.90%
# PC4:    Cummulative variance:  52.24%,  Individual variance:  2.90%
# PC5:    Cummulative variance:  55.04%,  Individual variance:  2.80%
# PC6:    Cummulative variance:  57.18%,  Individual variance:  2.14%
# PC7:    Cummulative variance:  59.08%,  Individual variance:  1.90%
# PC8:    Cummulative variance:  60.67%,  Individual variance:  1.59%
# PC9:    Cummulative variance:  62.24%,  Individual variance:  1.56%
# PC10:   Cummulative variance:  63.63%,  Individual variance:  1.40%

# %%
loadings = pca.components_
feature_names = df_pca.columns

loadings_df = pd.DataFrame(loadings.T, columns=[f'PC{i+1}' for i in range(loadings.shape[0])], index=feature_names)

plt.figure(figsize=(15,25))
sns.heatmap(loadings_df.iloc[:, :10], annot=True, cmap='coolwarm', center=0)
plt.title('Feature Loadings for Principal Components')
plt.show()

for i in range(1,21):
    pc_name = f'PC{i}'
    pc_loadings = loadings_df[pc_name].sort_values(ascending=False)
    print(f"Top contributing features for {pc_name} :")
    print(pc_loadings.head(20))
    print('\n')
# Out:
# Top contributing features for PC1 :
# lh_G_front_middle_thickness           0.145231
# lh_S_front_sup_thickness              0.144733
# lh_G_front_sup_thickness              0.144685
# rh_G_front_middle_thickness           0.143183
# rh_G_front_sup_thickness              0.142935
# rh_S_front_sup_thickness              0.142642
# lh_G_pariet_inf-Supramar_thickness    0.140765
# rh_G_pariet_inf-Supramar_thickness    0.140219
# rh_S_temporal_sup_thickness           0.139981
# lh_S_front_inf_thickness              0.138412
# lh_S_postcentral_thickness            0.138141
# lh_G_pariet_inf-Angular_thickness     0.137753
# rh_S_front_inf_thickness              0.136512
# lh_S_temporal_sup_thickness           0.136378
# rh_G_pariet_inf-Angular_thickness     0.136258
# lh_S_precentral-inf-part_thickness    0.134222
# rh_S_precentral-inf-part_thickness    0.134081
# rh_G_precuneus_thickness              0.134030
# lh_G_parietal_sup_thickness           0.133810
# rh_S_postcentral_thickness            0.133132
# Name: PC1, dtype: float64
#
#
# Top contributing features for PC2 :
# Right-VentralDC                  0.250953
# Left-VentralDC                   0.250174
# Brain-Stem                       0.242014
# Right-Pallidum                   0.218462
# Right-Cerebellum-Cortex          0.215171
# Left-Pallidum                    0.214671
# Left-Cerebellum-Cortex           0.210104
# Right-Putamen                    0.206051
# Left-Putamen                     0.205605
# Right-Caudate                    0.202082
# Left-Caudate                     0.198941
# Right-Amygdala                   0.195089
# Left-Cerebellum-White-Matter     0.189774
# Right-Hippocampus                0.183150
# Left-Hippocampus                 0.180790
# Sex                              0.179459
# Right-Cerebellum-White-Matter    0.175665
# Left-Amygdala                    0.174799
# Right-Accumbens-area             0.153089
# Left-Accumbens-area              0.137256
# Name: PC2, dtype: float64
#
#
# Top contributing features for PC3 :
# Left-Lateral-Ventricle         0.305909
# Right-Lateral-Ventricle        0.303928
# 3rd-Ventricle                  0.278994
# Left-Inf-Lat-Vent              0.275942
# Left-choroid-plexus            0.261703
# Right-Inf-Lat-Vent             0.246815
# Right-choroid-plexus           0.226598
# CSF                            0.210722
# Age                            0.198630
# WM-hypointensities             0.163549
# 4th-Ventricle                  0.141763
# Optic-Chiasm                   0.126143
# rh_G_cuneus_thickness          0.099079
# Sex                            0.084392
# Right-Caudate                  0.081342
# lh_S_central_thickness         0.080821
# rh_Pole_occipital_thickness    0.079056
# lh_Pole_occipital_thickness    0.068630
# Left-Caudate                   0.068092
# rh_S_central_thickness         0.063394
# Name: PC3, dtype: float64
#
#
# Top contributing features for PC4 :
# rh_Pole_occipital_thickness           0.323948
# rh_G_occipital_sup_thickness          0.255500
# rh_G_cuneus_thickness                 0.239678
# rh_G_precentral_thickness             0.203224
# rh_G_postcentral_thickness            0.202622
# rh_G_occipital_middle_thickness       0.197595
# rh_G_pariet_inf-Angular_thickness     0.145408
# rh_G_parietal_sup_thickness           0.142055
# rh_G_oc-temp_lat-fusifor_thickness    0.134717
# rh_G_temporal_middle_thickness        0.125697
# rh_S_central_thickness                0.123788
# Left-Accumbens-area                   0.116109
# Left-Putamen                          0.109010
# Right-Accumbens-area                  0.107428
# Right-Putamen                         0.101663
# rh_G_pariet_inf-Supramar_thickness    0.098567
# lh_Pole_occipital_thickness           0.097425
# rh_G_precuneus_thickness              0.095839
# Right-vessel                          0.091485
# rh_G_temp_sup-Lateral_thickness       0.089981
# Name: PC4, dtype: float64
#
#
# Top contributing features for PC5 :
# lh_Pole_occipital_thickness           0.281948
# lh_G_oc-temp_med-Parahip_thickness    0.257791
# lh_G_oc-temp_med-Lingual_thickness    0.229756
# lh_S_pericallosal_thickness           0.200165
# lh_G_occipital_middle_thickness       0.188193
# lh_Pole_temporal_thickness            0.164591
# lh_G_temporal_middle_thickness        0.159115
# Left-Accumbens-area                   0.152335
# lh_S_temporal_inf_thickness           0.151509
# lh_G_temp_sup-Lateral_thickness       0.139745
# Right-Accumbens-area                  0.135184
# lh_G_postcentral_thickness            0.133258
# lh_S_calcarine_thickness              0.122980
# lh_G_orbital_thickness                0.119930
# lh_G_temporal_inf_thickness           0.115910
# Left-Putamen                          0.115053
# lh_G_oc-temp_lat-fusifor_thickness    0.110107
# lh_S_collat_transv_ant_thickness      0.103395
# Right-Putamen                         0.101830
# lh_G_precentral_thickness             0.101182
# Name: PC5, dtype: float64
#
#
# Top contributing features for PC6 :
# CC_Posterior                          0.346526
# CC_Mid_Posterior                      0.323050
# CC_Anterior                           0.270992
# CC_Central                            0.265602
# CC_Mid_Anterior                       0.261844
# lh_G_oc-temp_med-Lingual_thickness    0.212276
# lh_Pole_occipital_thickness           0.201289
# lh_G_postcentral_thickness            0.165837
# lh_G_parietal_sup_thickness           0.139229
# lh_G_precentral_thickness             0.133066
# WM-hypointensities                    0.127222
# Left-Caudate                          0.121786
# Right-Caudate                         0.112433
# lh_G_occipital_middle_thickness       0.107738
# rh_Pole_occipital_thickness           0.086363
# rh_G_cuneus_thickness                 0.078339
# Right-Lateral-Ventricle               0.076117
# lh_G_front_sup_thickness              0.074740
# Left-Lateral-Ventricle                0.072505
# Right-Pallidum                        0.071264
# Name: PC6, dtype: float64
#
#
# Top contributing features for PC7 :
# rh_Pole_occipital_thickness           0.273128
# rh_G_cuneus_thickness                 0.254575
# Site                                  0.250456
# lh_Pole_occipital_thickness           0.223123
# Left-Cerebellum-Cortex                0.216449
# Right-Cerebellum-Cortex               0.208094
# lh_G_oc-temp_med-Lingual_thickness    0.207759
# rh_G_occipital_sup_thickness          0.170235
# Left-Cerebellum-White-Matter          0.147840
# rh_S_calcarine_thickness              0.121847
# Brain-Stem                            0.119452
# Right-Cerebellum-White-Matter         0.116378
# lh_G_oc-temp_med-Parahip_thickness    0.098798
# lh_S_calcarine_thickness              0.091780
# CC_Central                            0.084424
# rh_G_occipital_middle_thickness       0.082695
# Left-VentralDC                        0.077980
# 3rd-Ventricle                         0.077410
# Sex                                   0.070380
# lh_G_occipital_middle_thickness       0.070150
# Name: PC7, dtype: float64
#
#
# Top contributing features for PC8 :
# lh_G_precentral_thickness             0.233831
# Left-Cerebellum-White-Matter          0.222264
# Right-Cerebellum-White-Matter         0.218936
# lh_G_postcentral_thickness            0.182182
# lh_S_central_thickness                0.160361
# lh_S_precentral-sup-part_thickness    0.156616
# rh_G_precentral_thickness             0.140213
# Brain-Stem                            0.131861
# lh_G_parietal_sup_thickness           0.123624
# lh_G_front_sup_thickness              0.120302
# lh_G_front_middle_thickness           0.113722
# lh_S_postcentral_thickness            0.109194
# rh_S_precentral-sup-part_thickness    0.106681
# Right-Cerebellum-Cortex               0.094301
# Left-Cerebellum-Cortex                0.094042
# lh_S_front_sup_thickness              0.089537
# Left-VentralDC                        0.081868
# rh_G_postcentral_thickness            0.080392
# Right-VentralDC                       0.076635
# lh_S_precentral-inf-part_thickness    0.074513
# Name: PC8, dtype: float64
#
#
# Top contributing features for PC9 :
# Right-Cerebellum-White-Matter         0.292496
# Left-Cerebellum-White-Matter          0.265185
# lh_S_pericallosal_thickness           0.207992
# rh_S_pericallosal_thickness           0.174661
# CC_Posterior                          0.166016
# rh_G_temporal_middle_thickness        0.160370
# Right-choroid-plexus                  0.144098
# rh_G_temp_sup-Lateral_thickness       0.141861
# Left-Cerebellum-Cortex                0.133215
# lh_G_temp_sup-Lateral_thickness       0.132298
# lh_G_temporal_middle_thickness        0.129306
# Left-choroid-plexus                   0.127645
# CC_Anterior                           0.126099
# rh_G_pariet_inf-Angular_thickness     0.125931
# lh_Pole_temporal_thickness            0.123142
# Brain-Stem                            0.122280
# Right-Cerebellum-Cortex               0.116017
# rh_G_temporal_inf_thickness           0.112548
# rh_G_occipital_middle_thickness       0.099210
# rh_G_pariet_inf-Supramar_thickness    0.092719
# Name: PC9, dtype: float64
#
#
# Top contributing features for PC10 :
# rh_S_pericallosal_thickness         0.316841
# Left-Caudate                        0.244172
# lh_S_pericallosal_thickness         0.240331
# Right-Pallidum                      0.238211
# Right-Caudate                       0.226677
# Left-Pallidum                       0.226621
# WM-hypointensities                  0.213860
# lh_S_collat_transv_ant_thickness    0.151885
# Site                                0.140699
# Right-Cerebellum-White-Matter       0.133418
# Left-Cerebellum-White-Matter        0.132727
# Right-Putamen                       0.130314
# Left-Putamen                        0.118606
# Age                                 0.094600
# Brain-Stem                          0.071175
# lh_S_temporal_inf_thickness         0.070422
# rh_G_cuneus_thickness               0.068725
# rh_S_calcarine_thickness            0.067937
# lh_S_orbital-H_Shaped_thickness     0.054032
# rh_S_occipital_ant_thickness        0.052136
# Name: PC10, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/norm_vae/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PC11'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 13
#      11 for i in range(1,21):
#      12     pc_name = f'PC{i}'
# ---> 13     pc_loadings = loadings_df[pc_name].sort_values(ascending=False)
#      14     print(f"Top contributing features for {pc_name} :")
#      15     print(pc_loadings.head(20))
#
# File ~/.conda/envs/norm_vae/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/.conda/envs/norm_vae/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'PC11'
