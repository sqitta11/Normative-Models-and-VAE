# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
pd.set_option('display.max_columns', None)
import copy
import os
import sklearn
from sklearn.model_selection import train_test_split
from pcntoolkit import NormData
import warnings
import logging
import pcntoolkit.util.output
from PIL import Image
from pcntoolkit import (
    BLR,
    BsplineBasisFunction,
    NormativeModel,
    NormData,
    load_fcon1000,
    plot_centiles_advanced,
    plot_qq,
    plot_ridge,
)


sns.set_style("darkgrid")

# Suppress some annoying warnings and logs
pymc_logger = logging.getLogger("pymc")

pymc_logger.setLevel(logging.WARNING)
pymc_logger.propagate = False

warnings.simplefilter(action="ignore", category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'
pcntoolkit.util.output.Output.set_show_messages(True)

pd.set_option('display.max_rows', 100)
#this code was needed to run the code below without errors
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context

print('test')
# Out:
# test

# %%
path = "/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/final_data"

euler_nr = pd.read_csv(os.path.join(path, "euler_nr_data.csv"))
datatable = pd.read_csv(os.path.join(path, "Final_data.csv"))

euler_nr = euler_nr[['SubjectID', 'avg_euler_centered_neg_sqrt']].copy()
df_ukb = datatable.merge(euler_nr, how="right")
df_ukb = df_ukb.iloc[:, 1:]
df_ukb = df_ukb.dropna(axis=1)

#these cols had only zeros (left-vessel had 0s in some cases but not all --> may fit a separate model for this)
df_ukb["avg_euler_centered_neg_sqrt"] = df_ukb["avg_euler_centered_neg_sqrt"].astype(float)
df_ukb = df_ukb[df_ukb["avg_euler_centered_neg_sqrt"] < 10.0]

df_ukb = df_ukb.drop(columns=['SubjectID','Year_initial_scan','Birthyear','avg_euler_centered_neg_sqrt','5th-Ventricle','Left-WM-hypointensities','Left-non-WM-hypointensities','Left-vessel','Left-WM-hypointensities','Left-non-WM-hypointensities','Right-WM-hypointensities','Right-non-WM-hypointensities', 'non-WM-hypointensities'])
df_ukb["Dataset"]= "UKB"
first_cols = ["Age", "Sex", "Site", "Dataset"]
other_cols = df_ukb.columns.difference(first_cols, sort=False)
df_ukb = df_ukb[first_cols + list(other_cols)]

# %%
df_o3 = pd.read_csv("/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/csv_files/Oasis3_data.csv")

#these cols had only zeros (left-vessel had 0s in some cases but not all --> may fit a separate model for this)
df_o3 = df_o3.drop(columns=['SubjectID','5th-Ventricle','Left-WM-hypointensities','Left-non-WM-hypointensities','Left-vessel','Left-WM-hypointensities','Left-non-WM-hypointensities','Right-WM-hypointensities','Right-non-WM-hypointensities'])

pd.set_option('display.max_columns', None)
df_o3 = df_o3.iloc[:,1:]

#split datasets into alzheimer vs healthy controls
alzheimer_df = df_o3[df_o3["Diagnosis"] >= 1.0]
healthy_controls_o3 = df_o3[df_o3["Diagnosis"] == 0.0]

#remove diagnosis from the Healthy control dataframe
healthy_controls_o3 = healthy_controls_o3.drop(columns=['Diagnosis'])

#order the HC the same way as the UKB dataset
ordering_ukb = list(df_ukb.columns)
healthy_controls_o3["Dataset"] = "OASIS3"
healthy_controls_o3 = healthy_controls_o3[ordering_ukb]
df_o3["Dataset"] = "OASIS3"

# %%
df_adni = pd.read_csv("/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/data_prep/ADNI_data.csv")
df_adni = df_adni.iloc[:,1:]
df_adni.replace(to_replace=['F'], value=0.0, inplace=True)
df_adni.replace(to_replace=['M'], value=1.0, inplace=True)
df_adni = df_adni[df_adni["Sex"] != "X"]
df_adni["Age"] = df_adni["Age"].round()
healthy_controls_adni = df_adni[df_adni["Group"] == "CN"]
healthy_controls_adni.drop(columns=["Group"])
healthy_controls_adni["Dataset"] = "ADNI"
healthy_controls_adni = healthy_controls_adni[ordering_ukb]
df_adni["Dataset"] = "ADNI"

grouped_data = healthy_controls_adni.groupby(['Site', 'Sex']).size().reset_index(name='Count')
plt.figure(figsize=(12, 6))
sns.barplot(data=grouped_data, x='Site', y='Count', hue='Sex',palette='plasma')
plt.title('Distribution of each sex by site for healthy controls ADNI')
plt.xlabel('Sites')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
df_o3["Age"].describe()

# adni_path = "/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/data_prep/"
# adni_data = pd.read_csv(os.path.join(adni_path, "ADNI_data.csv"))
# adni_data = adni_data.iloc[:,1:]
# adni_data["Sex"] = adni_data["Sex"].replace({"F":0, "M":1})
# adni_data = adni_data.rename(columns={"Group":"Diagnosis"})
# adni_data = adni_data[adni_data["Sex"] != "X"]
# adni_data = adni_data.drop(columns=["participant_id"])
# adni_data["Dataset"] = "ADNI"
# full_data = pd.concat([adni_data, df_o3, df_ukb], axis=0)
# full_data["Age"].describe()
# Out:
# count    1893.000000
# mean       69.767565
# std         9.387414
# min        43.000000
# 25%        64.000000
# 50%        70.000000
# 75%        76.000000
# max        97.000000
# Name: Age, dtype: float64

# %%
data_df = pd.concat([df_ukb, healthy_controls_o3, healthy_controls_adni], axis=0)

# data_df = data_df[data_df["Site"] != 27.0]
# data_df = data_df[data_df["Site"] != 51.0]
# data_df = data_df[data_df["Age"] != 95.0]
# data_df = data_df[data_df["Age"] != 97.0]

# %%
data_df = pd.concat([df_ukb, healthy_controls_o3, healthy_controls_adni], axis=0)

#removing sites with only 1 participant per sex [train_test_split error]
data_df = data_df[~data_df["Site"].isin([9.0, 10.0, 14.0, 16.0, 19.0, 20.0, 24.0, 27.0, 35.0, 51.0, 57.0, 68.0, 62.0, 67.0, 70.0, 114.0, 130.0, 133.0, 135.0, 136.0, 141.0, 153.0])]

#removing these ages because they had unique site & age combinations which could not be split 
data_df = data_df[data_df["Age"] != 96.0]
data_df = data_df[data_df["Age"] != 91.0]
data_df = data_df[data_df["Age"] != 95.0]
data_df = data_df[data_df["Age"] != 97.0]


data = data_df


data_df = data_df.drop(columns=['Age','Sex','Site','Dataset'])
columns = list(data_df.columns)

response_vars = columns

# create a NormData object
norm_data = NormData.from_dataframe(name="Final_BLR_uncorrected", dataframe=data, covariates=["Age"], batch_effects=None, response_vars=response_vars)
norm_data.coords

train_plt, test_plt = train_test_split(data, test_size=0.2, random_state=42)
train, test = norm_data.train_test_split()
# Out:
# Process: 1247912 - 2026-04-22 09:52:39 - Dataset "Final_BLR_uncorrected" created.
#     - 35378 observations
#     - 35378 unique subjects
#     - 1 covariates
#     - 103 response variables
#     - 1 batch effects:
#     	dummy_batch_effect (1)
# <xarray.NormData> Size: 28MB
# Dimensions:            (observations: 28302, response_vars: 103, covariates: 1,
#                         batch_effect_dims: 1)
# Coordinates:
#   * observations       (observations) int64 226kB 14652 19265 ... 23546 19215
#   * response_vars      (response_vars) <U34 14kB 'lh_G_front_inf-Triangul_thi...
#   * covariates         (covariates) <U3 12B 'Age'
#   * batch_effect_dims  (batch_effect_dims) <U18 72B 'dummy_batch_effect'
# Data variables:
#     subject_ids        (observations) int64 226kB 14652 19265 ... 23546 19215
#     Y                  (observations, response_vars) float64 23MB 2.607 ... 1...
#     X                  (observations, covariates) float64 226kB 64.0 ... 50.0
#     batch_effects      (observations, batch_effect_dims) <U32 4MB '0.0' ... '...
# Attributes:
#     real_ids:                       False
#     is_scaled:                      False
#     name:                           Final_BLR_uncorrected_train
#     unique_batch_effects:           {np.str_('dummy_batch_effect'): [np.str_(...
#     batch_effect_counts:            defaultdict(<function NormData.register_b...
#     covariate_ranges:               {np.str_('Age'): {'mean': np.float64(56.0...
#     batch_effect_covariate_ranges:  {np.str_('dummy_batch_effect'): {np.str_(...

# %%
template_blr = BLR(
    name="BLR_uncorrected_all_data",
    basis_function_mean=BsplineBasisFunction(
        degree=3, nknots=5 
    ),  # We use a B-spline basis expansion for the mean, so the predicted mean is a smooth function of the covariates
    fixed_effect=False,  # By setting fixed_effect=True, we \model offsets in the mean for each individual batch effect,
    heteroskedastic=True, #maybe True # We want the variance to be a function of the covariates too
    warp_name="warpsinharcsinh",  # We configure a sinh-arcsinh warp, so we can model flexible non-gaussian distributions
)

model = NormativeModel(
    # The regression model to use for the normative model.
    template_regression_model=template_blr,
    # Whether to save the model after fitting.
    savemodel=True,
    # Whether to evaluate the model after fitting.
    evaluate_model=True,
    # Whether to save the results after evaluation.
    saveresults=True,
    # Whether to save the plots after fitting.
    saveplots=True,
    # The directory to save the model, results, and plots.
    save_dir="/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/BLR/Final_BLRs/Final_BLR_uncorrected_results",
    # The scaler to use for the input data. Can be either one of "standardize", "minmax", "robminmax", "none"
    inscaler="standardize",
    # The scaler to use for the output data. Can be either one of "standardize", "minmax", "robminmax", "none"
    outscaler="standardize",
)

model.fit_predict(train, test)
# Out:
# Process: 1247912 - 2026-04-22 09:53:46 - Fitting models on 103 response variables.
# Process: 1247912 - 2026-04-22 09:53:46 - Fitting model for lh_G_front_inf-Triangul_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:53:49 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:53:49 - Fitting model for lh_G_front_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.81908e-78): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:53:52 - Estimation of posterior distribution failed due to:
# Matrix is not positive definite
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.21116e-78): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.64597e-78): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.0104e-78): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# Process: 1247912 - 2026-04-22 09:53:52 - Fitting model for lh_G_front_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:53:54 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:53:54 - Fitting model for lh_G_oc-temp_lat-fusifor_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:53:57 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:53:57 - Fitting model for lh_G_oc-temp_med-Lingual_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:00 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:00 - Fitting model for lh_G_oc-temp_med-Parahip_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:03 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:03 - Fitting model for lh_G_occipital_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/math_functions/warp.py:510: RuntimeWarning: overflow encountered in exp
#   b = np.exp(param[1])
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/math_functions/warp.py:530: RuntimeWarning: invalid value encountered in subtract
#   y = np.sinh(b * np.arcsinh(x) - a)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:07 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:07 - Fitting model for lh_G_orbital_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:54:09 - Fitting model for lh_G_pariet_inf-Angular_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:12 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:12 - Fitting model for lh_G_pariet_inf-Supramar_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:15 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:15 - Fitting model for lh_G_parietal_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:18 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:18 - Fitting model for lh_G_postcentral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.05008e-129): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.76647e-129): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:21 - Estimation of posterior distribution failed due to:
# Matrix is not positive definite
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:687: RuntimeWarning: overflow encountered in divide
#   df_dx = [delf / delx for delf, delx in zip(df, dx)]
# Process: 1247912 - 2026-04-22 09:54:21 - Fitting model for lh_G_precentral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:23 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:24 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:24 - Fitting model for lh_G_rectus_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:26 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:26 - Fitting model for lh_G_temp_sup-Lateral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:29 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:29 - Fitting model for lh_G_temp_sup-Plan_tempo_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:32 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:32 - Fitting model for lh_G_temporal_inf_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/math_functions/warp.py:510: RuntimeWarning: overflow encountered in exp
#   b = np.exp(param[1])
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/math_functions/warp.py:530: RuntimeWarning: invalid value encountered in subtract
#   y = np.sinh(b * np.arcsinh(x) - a)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:35 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:35 - Fitting model for lh_G_temporal_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:38 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:38 - Fitting model for lh_Pole_occipital_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:40 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:40 - Fitting model for lh_Pole_temporal_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:43 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:44 - Fitting model for lh_S_calcarine_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:54:46 - Fitting model for lh_S_central_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:49 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:49 - Fitting model for lh_S_collat_transv_ant_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:54:52 - Fitting model for lh_S_front_inf_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:54 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:54 - Fitting model for lh_S_front_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:57 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:54:57 - Fitting model for lh_S_front_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:54:59 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:00 - Fitting model for lh_S_occipital_ant_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:02 - Fitting model for lh_S_orbital-H_Shaped_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:06 - Fitting model for lh_S_pericallosal_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:09 - Fitting model for lh_S_postcentral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:11 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:11 - Fitting model for lh_S_precentral-inf-part_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:13 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:14 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:14 - Fitting model for lh_S_precentral-sup-part_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:16 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:16 - Fitting model for lh_S_temporal_inf_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: overflow encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:19 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:19 - Fitting model for lh_S_temporal_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:21 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:21 - Fitting model for rh_G_cuneus_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:24 - Fitting model for rh_G_front_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:27 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:27 - Fitting model for rh_G_front_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:29 - Fitting model for rh_G_oc-temp_lat-fusifor_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:32 - Fitting model for rh_G_occipital_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:35 - Fitting model for rh_G_occipital_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:37 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:37 - Fitting model for rh_G_orbital_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:40 - Fitting model for rh_G_pariet_inf-Angular_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:55:43 - Fitting model for rh_G_pariet_inf-Supramar_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:45 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:46 - Fitting model for rh_G_parietal_sup_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/math_functions/warp.py:530: RuntimeWarning: overflow encountered in sinh
#   y = np.sinh(b * np.arcsinh(x) - a)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:52 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:52 - Fitting model for rh_G_postcentral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:55 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:55 - Fitting model for rh_G_precentral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:55:57 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:55:57 - Fitting model for rh_G_precuneus_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:00 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:56:00 - Fitting model for rh_G_temp_sup-Lateral_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:03 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:56:03 - Fitting model for rh_G_temp_sup-Plan_tempo_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:05 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:56:05 - Fitting model for rh_G_temporal_inf_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:729: RuntimeWarning: divide by zero encountered in log
#   logdetSigma_n = -np.sum(np.log(self.lambda_n_vec))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:743: RuntimeWarning: divide by zero encountered in log
#   nlZ = nlZ - np.sum(np.log(self.warp.df(y_unwarped, gamma)))
# Process: 1247912 - 2026-04-22 09:56:08 - Fitting model for rh_G_temporal_middle_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:595: RuntimeWarning: overflow encountered in exp
#   beta = np.exp(Phi_var.dot(w_d))
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:672: RuntimeWarning: invalid value encountered in multiply
#   XtLambda_n = X.T * self.lambda_n_vec
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/regression_model/blr.py:673: RuntimeWarning: invalid value encountered in dot
#   self.A = XtLambda_n.dot(X) + self.Lambda_a
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:10 - Estimation of posterior distribution failed due to:
# LAPACK reported an illegal value in 5-th argument.
#   warnings.warn(message)
# Process: 1247912 - 2026-04-22 09:56:11 - Fitting model for rh_Pole_occipital_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:13 - Estimation of posterior distribution failed due to:
# Matrix is singular.
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.90186e-242): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:13 - Estimation of posterior distribution failed due to:
# Matrix is not positive definite
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.1377e-242): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# Process: 1247912 - 2026-04-22 09:56:13 - Fitting model for rh_S_calcarine_thickness.
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.99876e-81): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/pcntoolkit/util/output.py:239: UserWarning: Process: 1247912 - 2026-04-22 09:56:16 - Estimation of posterior distribution failed due to:
# Matrix is not positive definite
#   warnings.warn(message)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.72278e-81): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.23757e-81): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /home/preclineu/quirom/.conda/envs/norm_vae/lib/python3.12/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.83999e-81): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# Process: 1247912 - 2026-04-22 09:56:16 - Fitting model for rh_S_central_thickness.
# ...
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_S_interm_prim-Jensen_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_temporal_middle_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_orbital_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_front_inf-Triangul_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_precentral-inf-part_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_S_precentral-sup-part_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_temporal_inf_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_occipital_ant_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Inf-Lat-Vent.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_pariet_inf-Supramar_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for CC_Central.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_central_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_Pole_occipital_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-Accumbens-area.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_S_occipital_ant_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_pariet_inf-Angular_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_occipital_middle_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_postcentral_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for WM-hypointensities.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for CC_Mid_Posterior.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-Pallidum.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_parietal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-Amygdala.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Lateral-Ventricle.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_temp_sup-Plan_tempo_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-Cerebellum-White-Matter.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Amygdala.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_cuneus_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_orbital_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_S_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_calcarine_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_oc-temp_lat-fusifor_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Cerebellum-Cortex.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_Pole_temporal_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Caudate.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Accumbens-area.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-Cerebellum-White-Matter.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_oc-temp_med-Lingual_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_rectus_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_S_oc-temp_lat_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for CC_Anterior.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-choroid-plexus.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-choroid-plexus.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_temporal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Brain-Stem.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Left-Hippocampus.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_pariet_inf-Angular_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_S_precentral-sup-part_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_G_parietal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for Right-VentralDC.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for rh_Pole_occipital_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Computing centiles for lh_G_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data on 103 response variables.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data for Left-VentralDC.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data for Right-Hippocampus.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data for rh_S_central_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data for rh_G_precentral_thickness.
# Process: 1247912 - 2026-04-22 10:07:59 - Harmonizing data for lh_G_oc-temp_med-Parahip_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_precentral-inf-part_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CC_Mid_Anterior.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for 3rd-Ventricle.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_pericallosal_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CSF.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Lateral-Ventricle.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_temp_sup-Lateral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_temp_sup-Plan_tempo_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CC_Posterior.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_front_inf_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for 4th-Ventricle.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Pallidum.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_postcentral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_front_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_front_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_occipital_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_temp_sup-Lateral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_postcentral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_calcarine_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_orbital-H_Shaped_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_cingul-Marginalis_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_temporal_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_oc-temp_lat-fusifor_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_postcentral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_precentral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Putamen.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_temporal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_pericallosal_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_pariet_inf-Supramar_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-vessel.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_collat_transv_ant_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Putamen.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Optic-Chiasm.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_temporal_inf_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_front_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_front_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_precuneus_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_occipital_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_temporal_inf_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_parieto_occipital_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Inf-Lat-Vent.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Cerebellum-Cortex.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_front_inf_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Caudate.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_interm_prim-Jensen_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_temporal_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_orbital_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_front_inf-Triangul_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_precentral-inf-part_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_precentral-sup-part_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_temporal_inf_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_occipital_ant_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Inf-Lat-Vent.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_pariet_inf-Supramar_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CC_Central.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_central_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_Pole_occipital_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Accumbens-area.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_occipital_ant_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_pariet_inf-Angular_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_occipital_middle_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_postcentral_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for WM-hypointensities.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CC_Mid_Posterior.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Pallidum.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_parietal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Amygdala.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Lateral-Ventricle.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_temp_sup-Plan_tempo_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Cerebellum-White-Matter.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Amygdala.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_cuneus_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_orbital_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_calcarine_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_G_oc-temp_lat-fusifor_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Cerebellum-Cortex.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_Pole_temporal_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Caudate.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Accumbens-area.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-Cerebellum-White-Matter.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_oc-temp_med-Lingual_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_rectus_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for rh_S_oc-temp_lat_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for CC_Anterior.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Right-choroid-plexus.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-choroid-plexus.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_S_temporal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Brain-Stem.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for Left-Hippocampus.
# Process: 1247912 - 2026-04-22 10:08:00 - Harmonizing data for lh_G_pariet_inf-Angular_thickness.
# Process: 1247912 - 2026-04-22 10:08:01 - Harmonizing data for lh_S_precentral-sup-part_thickness.
# Process: 1247912 - 2026-04-22 10:08:01 - Harmonizing data for rh_G_parietal_sup_thickness.
# Process: 1247912 - 2026-04-22 10:08:01 - Harmonizing data for Right-VentralDC.
# Process: 1247912 - 2026-04-22 10:08:01 - Harmonizing data for rh_Pole_occipital_thickness.
# Process: 1247912 - 2026-04-22 10:08:01 - Harmonizing data for lh_G_front_sup_thickness.
# Process: 1247912 - 2026-04-22 10:09:01 - Saving model to:
# 	/home/preclineu/quirom/Desktop/internship/Normative-Models-and-VAE/logs/BLR/Final_BLRs/Final_BLR_uncorrected_results.
# <xarray.NormData> Size: 59MB
# Dimensions:            (observations: 7076, response_vars: 103, covariates: 1,
#                         batch_effect_dims: 1, centile: 5, statistic: 11)
# Coordinates:
#   * observations       (observations) int64 57kB 27898 10326 ... 34782 27747
#   * response_vars      (response_vars) <U34 14kB 'lh_G_front_inf-Triangul_thi...
#   * covariates         (covariates) <U3 12B 'Age'
#   * batch_effect_dims  (batch_effect_dims) <U18 72B 'dummy_batch_effect'
#   * centile            (centile) float64 40B 0.05 0.25 0.5 0.75 0.95
#   * statistic          (statistic) <U8 352B 'EXPV' 'MACE' ... 'SMSE' 'ShapiroW'
# Data variables:
#     subject_ids        (observations) int64 57kB 27898 10326 ... 34782 27747
#     Y                  (observations, response_vars) float64 6MB 2.75 ... 3.7...
#     X                  (observations, covariates) float64 57kB 53.0 ... 69.0
#     batch_effects      (observations, batch_effect_dims) <U32 906kB '0.0' ......
#     Z                  (observations, response_vars) float64 6MB -0.6027 ... ...
#     centiles           (centile, observations, response_vars) float64 29MB 2....
#     logp               (observations, response_vars) float64 6MB -0.9333 ... ...
#     Yhat               (observations, response_vars) float64 6MB 2.849 ... 4....
#     statistics         (response_vars, statistic) float64 9kB 0.1525 ... 0.7559
#     Y_harmonized       (observations, response_vars) float64 6MB 2.75 ... 3.7...
# Attributes:
#     real_ids:                       False
#     is_scaled:                      False
#     name:                           Final_BLR_uncorrected_test
#     unique_batch_effects:           {np.str_('dummy_batch_effect'): [np.str_(...
#     batch_effect_counts:            defaultdict(<function NormData.register_b...
#     covariate_ranges:               {np.str_('Age'): {'mean': np.float64(56.0...
#     batch_effect_covariate_ranges:  {np.str_('dummy_batch_effect'): {np.str_(...
